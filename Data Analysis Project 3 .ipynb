# %% [markdown]
# # Police Traffic Stop Datset
#
# This data is avalible as a csv file. We are going to analyze this set using the Panda DataFrame

# %%
import pandas as pd

# %%
data = pd.read_csv(r'D:\Data Projects Files\DSL Projects\3. Police Data.csv')

# %%
data

# %% [markdown]
# ### Instruction ( For Data Cleaning )
# # 1. Remove the column that only contains missing values.

# %%
# df.isnull().sum()

#df.drop( columns = 'column_name' , inplace = true )

# %%
data.isnull()
# Out:
#        stop_date  stop_time  driver_gender  driver_age_raw  driver_age  \
# 0          False      False          False           False       False
# 1          False      False          False           False       False
# 2          False      False          False           False       False
# 3          False      False          False           False       False
# 4          False      False          False           False       False
# ...          ...        ...            ...             ...         ...
# 65530      False      False          False           False       False
# 65531      False      False          False           False       False
# 65532      False      False          False           False       False
# 65533      False      False           True            True        True
# 65534      False      False          False           False       False
#
#        driver_race  violation_raw  violation  search_conducted  search_type  \
# ...

# %%
data.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
data.drop(columns = 'country_name', inplace = True)

# %%
data.head()  # dropped the column country name with only null
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
#   is_arrested stop_duration  drugs_related_stop
# ...

# %% [markdown]
# ### ( Based on Filtering + Value Counts )
# # 2. For Speeding , were Men or Women stopped more often ?

# %%
# df[df.Column_1 == 'Element/Value'}.Column_2.value_counts()

# %%
data.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
#   is_arrested stop_duration  drugs_related_stop
# ...

# %%
data['violation_raw'].unique()
# Out:
# array(['Speeding', 'Call for Service', 'Equipment/Inspection Violation',
#        'Other Traffic Violation', nan, 'Registration Violation',
#        'Special Detail/Directed Patrol', 'APB',
#        'Violation of City/Town Ordinance', 'Suspicious Person',
#        'Motorist Assist/Courtesy', 'Warrant', 'Seatbelt Violation'],
#       dtype=object)

# %%
data[data.violation == 'Speeding']
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# 6       4/1/2005     17:30             M          1969.0        36.0
# ...          ...       ...           ...             ...         ...
# 65527  12/6/2012     15:26             F          1981.0        31.0
# 65529  12/6/2012     16:00             M          1994.0        18.0
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race violation_raw violation  search_conducted search_type  \
# ...

# %%
data[data.violation == 'Speeding'].driver_gender.value_counts()  # men were stopped more often
# Out:
# M    25517
# F    11686
# Name: driver_gender, dtype: int64

# %% [markdown]
# ### Question ( Groupby )
# # 3. Does gender affect who gets searched during a stop ?

# %%
# df.groupby('Column_1').Column_2.sum()

# %%
data.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
#   is_arrested stop_duration  drugs_related_stop
# ...

# %%
data.groupby('driver_gender').search_conducted.sum() #driver search was conducted on males more
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %%
data.search_conducted.value_counts()
# Out:
# False    63056
# True      2479
# Name: search_conducted, dtype: int64

# %% [markdown]
# ### Question ( mapping + data-type casting )
# # 4. What is the mean stop_duration ?

# %%
# df['Column_name'] = df['Column_name'].map( { old:new, old:new})

# df['Column_name'].mean()

# %%
data.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
#   is_arrested stop_duration  drugs_related_stop
# ...

# %%
# need to convert column stop duration to integer to run mean 
data.stop_duration.unique()
# Out:
# array(['0-15 Min', '16-30 Min', '30+ Min', nan, '2'], dtype=object)

# %%
data.stop_duration.value_counts()
# Out:
# 0-15 Min     47379
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: stop_duration, dtype: int64

# %%
data['stop_duration'] = data['stop_duration'].map({ '0-15 Min': 7.5 , '16-30 Min': 24, '30+ Min': 45 })

# %%
data
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
data['stop_duration'].mean()  # mean of stop duratioin is 12.187
# Out:
# 12.187420698181345

# %% [markdown]
# ### ( Groupby , Describe )
# # 5. Compare the age distributions for each violation.

# %%
# df.groupby('Column_1').Column_2.describe()

# %%
data.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
#   is_arrested  stop_duration  drugs_related_stop
# ...

# %%
data.groupby('driver_age').violation.describe()
# Out:
#            count unique               top  freq
# driver_age
# 15.0           5      2  Moving violation     4
# 16.0          34      5          Speeding    18
# 17.0         449      5          Speeding   338
# 18.0        1344      5          Speeding   980
# 19.0        2388      5          Speeding  1655
# ...          ...    ...               ...   ...
# 83.0           2      2          Speeding     1
# 84.0           3      1          Speeding     3
# 85.0           1      1  Moving violation     1
# 86.0           6      3          Speeding     3
# 88.0           2      1          Speeding     2
#
# [73 rows x 4 columns]

# %%
data.groupby('violation').driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             6507.0  31.682957  11.380671  16.0  23.0  28.0  39.0
# Moving violation     11876.0  36.736443  13.258350  15.0  25.0  35.0  47.0
# Other                 3477.0  40.362381  12.754423  16.0  30.0  41.0  50.0
# Registration/plates   2240.0  32.656696  11.150780  16.0  24.0  30.0  40.0
# Seat belt                3.0  30.333333  10.214369  23.0  24.5  26.0  34.0
# Speeding             37120.0  33.262581  12.615781  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  74.0
# Seat belt            42.0
# Speeding             88.0
